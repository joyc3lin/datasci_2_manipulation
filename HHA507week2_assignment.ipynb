# %% [markdown]
# <a href="https://colab.research.google.com/github/joyc3lin/datasci_2_manipulation/blob/main/HHA507week2_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # **Loading the Dataset**

# %%
df = pd.read_csv('https://raw.githubusercontent.com/hantswilliams/HHA_507_2023/main/WK2/data/healthcare_data_cleaning.csv')
df
# Out:
#        Patient Age  Gender  City of Residence State of Residence  \
# 0               45   Other         West Brian           Kentucky
# 1               25  Female   East Jocelynfurt           Colorado
# 2               51   Other  South Lindseyland               Ohio
# 3               18  Female         Taylorfort       Pennsylvania
# 4               48  Female          Birdmouth            Montana
# ...            ...     ...                ...                ...
# 104995          74   Other       West Anthony           Oklahoma
# 104996          37    Male          Mckeetown               Utah
# 104997          51  Female   Lake Lisachester           Nebraska
# 104998     missing  Female       Heidiborough            missing
# 104999          45  Female      South Jeffrey      Massachusetts
#
#        Has Insurance Visited Last Month Payment Method Preferred Doctor  \
# 0                Yes                Yes      Insurance     Dr. Williams
# ...

# %% [markdown]
# ## **1. Data Cleaning with Pandas**

# %% [markdown]
# ## Identifying and handling the missing values

# %%
#converting missing to null
df.replace('missing', pd.np.nan , inplace=True)
df
# Out:
# <ipython-input-111-e6292d00fb23>:2: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   df.replace('missing', pd.np.nan , inplace=True)
#        Patient Age  Gender  City of Residence State of Residence  \
# 0               45   Other         West Brian           Kentucky
# 1               25  Female   East Jocelynfurt           Colorado
# 2               51   Other  South Lindseyland               Ohio
# 3               18  Female         Taylorfort       Pennsylvania
# 4               48  Female          Birdmouth            Montana
# ...            ...     ...                ...                ...
# 104995          74   Other       West Anthony           Oklahoma
# 104996          37    Male          Mckeetown               Utah
# 104997          51  Female   Lake Lisachester           Nebraska
# 104998         NaN  Female       Heidiborough                NaN
# ...

# %%
#checking cell types
print(df['Patient Age'].isnull().sum())

for c in df.columns:
  print(f"{c}: {type(df[c][0])}")
# Out:
# 5249
# Patient Age: <class 'str'>
# Gender: <class 'str'>
# City of Residence: <class 'str'>
# State of Residence: <class 'str'>
# Has Insurance: <class 'str'>
# Visited Last Month: <class 'str'>
# Payment Method: <class 'str'>
# Preferred Doctor: <class 'str'>
# Disease Diagnosed: <class 'str'>
# Medication Prescribed: <class 'str'>
# Type of Appointment: <class 'str'>
# Average Heart Rate: <class 'str'>
# Average BP: <class 'str'>
# Height (in cm): <class 'str'>
# Weight (in kg): <class 'str'>
# Payment Due ($): <class 'str'>
# Last Visit (days ago): <class 'str'>
# Visit Duration (mins): <class 'str'>
# Number of Tests: <class 'str'>
# Prescription Cost ($): <class 'str'>

# %%
#code for replacing missing cell values with average of column
#df['Patient Age'] = pd.to_numeric(df['Patient Age'], errors = "coerce")
#df['Patient Age'].fillna(df['Patient Age'].mean(), inplace=True)
#df

# %%
#dropping rows with missing data
df.dropna(inplace=True)
print(df.shape)
df
# Out:
# (37594, 20)
#        Patient Age  Gender City of Residence State of Residence Has Insurance  \
# 0               45   Other        West Brian           Kentucky           Yes
# 4               48  Female         Birdmouth            Montana            No
# 7               52    Male      Vanessaburgh        Connecticut           Yes
# 8               20  Female  West Briannabury            Montana            No
# 11              40  Female        Jonesmouth       Rhode Island            No
# ...            ...     ...               ...                ...           ...
# 104992          44  Female    Port Tracistad             Alaska           Yes
# 104993          42  Female     West Annaport            Florida           Yes
# 104994          53  Female     Michelleburgh       South Dakota            No
# 104995          74   Other      West Anthony           Oklahoma           Yes
# 104997          51  Female  Lake Lisachester           Nebraska           Yes
#
# ...

# %% [markdown]
# ## Removing duplicate rows and columns

# %%
df.drop_duplicates(inplace=True)
print(df.shape)
# Out:
# (35828, 20)

# %% [markdown]
# ## Cleaning Column Names

# %%
import re

# %%
# Function to remove white space and special characters from a value
def clean_value(value):
    cleaned_value = re.sub(r'\s+|[^a-zA-Z0-9]', '', str(value))
    return cleaned_value

# Apply the clean_value function to all columns
#for column in df.columns:
    #df[column] = df[column].apply(clean_value)

# renames headers
df.rename(mapper=clean_value, axis=1, inplace=True)

df
# Out:
#        PatientAge  Gender   CityofResidence StateofResidence HasInsurance  \
# 0              45   Other        West Brian         Kentucky          Yes
# 4              48  Female         Birdmouth          Montana           No
# 7              52    Male      Vanessaburgh      Connecticut          Yes
# 8              20  Female  West Briannabury          Montana           No
# 11             40  Female        Jonesmouth     Rhode Island           No
# ...           ...     ...               ...              ...          ...
# 104992         44  Female    Port Tracistad           Alaska          Yes
# 104993         42  Female     West Annaport          Florida          Yes
# 104994         53  Female     Michelleburgh     South Dakota           No
# 104995         74   Other      West Anthony         Oklahoma          Yes
# 104997         51  Female  Lake Lisachester         Nebraska          Yes
#
#        VisitedLastMonth PaymentMethod PreferredDoctor DiseaseDiagnosed  \
# ...

# %% [markdown]
# # **2. Data Transformations**

# %% [markdown]
# ## creating new column

# %%
# turning values in PaymentDue and PrescriptionCost into floats
df['PaymentDue'] = pd.to_numeric(df['PaymentDue'], errors = "coerce")
df['PrescriptionCost'] = pd.to_numeric(df['PrescriptionCost'], errors = "coerce")

# %%
# adding TotalPaymentDue column that adds values of PaymentDue and PrescriptionCost columns
df['TotalPaymentDue'] = df['PaymentDue'] + df['PrescriptionCost']
df
# Out:
#        PatientAge  Gender   CityofResidence StateofResidence HasInsurance  \
# 0              45   Other        West Brian         Kentucky          Yes
# 4              48  Female         Birdmouth          Montana           No
# 7              52    Male      Vanessaburgh      Connecticut          Yes
# 8              20  Female  West Briannabury          Montana           No
# 11             40  Female        Jonesmouth     Rhode Island           No
# ...           ...     ...               ...              ...          ...
# 104992         44  Female    Port Tracistad           Alaska          Yes
# 104993         42  Female     West Annaport          Florida          Yes
# 104994         53  Female     Michelleburgh     South Dakota           No
# 104995         74   Other      West Anthony         Oklahoma          Yes
# 104997         51  Female  Lake Lisachester         Nebraska          Yes
#
#        VisitedLastMonth PaymentMethod PreferredDoctor DiseaseDiagnosed  \
# ...
